# %%
#pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import google.generativeai as genai

genai.configure(api_key="YOUR_API_KEY_HERE")
model = genai.GenerativeModel("gemini-3.6-flash")
response = model.generate_content("Explain how AI works")
print(response.text)
# Out:
# At its most basic level, **Artificial Intelligence (AI) works by recognizing patterns in massive amounts of data and using those patterns to make predictions or decisions.**
#
# To understand AI, it helps to contrast it with traditional computer programming:
#
# *   **Traditional Software:** A human writes explicit step-by-step rules. *(e.g., "If the user clicks this button, open page X.")*
# *   **Artificial Intelligence:** A human feeds the computer millions of examples, and **the computer figures out the rules itself.**
#
# Here is a step-by-step breakdown of how modern AI actually works.
#
# ---
#
# ### 1. The Three Main Ingredients
#
# Every modern AI system relies on three things:
#
# 1.  **Data (The Fuel):** Images, text, audio, medical scans, or numbers. An AI needs massive amounts of examples to learn.
# 2.  **Algorithms (The Math):** Sets of mathematical rules that tell the computer how to search for patterns in the data.
# 3.  **Compute Power (The Engine):** Specialized microchips (like GPUs) that can process trillions of mathematical calculations per second.
#
# ---
#
# ### 2. How AI "Learns" (Machine Learning)
#
# The primary way we build AI today is through **Machine Learning (ML)**. Here is how a system learns to do a task, like identifying a cat in a photo:
#
# *   **Step 1: Inputting Data:** You give the computer 100,000 labeled photos—50,000 cats and 50,000 dogs.
# *   **Step 2: Guessing:** The AI looks at a new photo. At first, it knows nothing, so it makes a completely random guess: *"That's a dog."*
# *   **Step 3: Calculating Error:** You tell the AI, *"Wrong, it was a cat."* The system calculates how far off its guess was.
# *   **Step 4: Adjusting (Training):** The AI automatically tweaks its internal mathematical settings (called **weights**) to lessen the chance of making that same mistake again. Think of it like tuning millions of tiny dials on a radio until the signal becomes clear.
# *   **Step 5: Repeating:** The AI repeats this guess-and-adjust process millions of times. Eventually, it learns that pointy ears, whiskers, and specific pixel arrangements usually mean "cat."
#
# ---
#
# ### 3. Deep Learning and Neural Networks
#
# For complex tasks—like driving a car or understanding speech—AI uses a technique called **Deep Learning**, which relies on **Artificial Neural Networks**.
#
# These networks are loosely inspired by the human brain:
# *   They consist of layers of interconnected math nodes ("neurons").
# *   **The Input Layer** takes in raw data (e.g., pixels of an image).
# *   **The Hidden Layers** process the data in stages. The first layer might detect simple lines and edges; the next layer detects shapes (circles, triangles); the next layer detects features (eyes, wheels); and so on.
# *   **The Output Layer** makes the final decision (e.g., "This is a stop sign").
#
# ---
#
# ### 4. How Generative AI Works (e.g., ChatGPT, Midjourney)
#
# Generative AI doesn't just recognize patterns; it uses them to **create new content**.
#
# *   **Large Language Models (LLMs) like ChatGPT:** They were trained by reading billions of pages of text from the internet. By doing this, the AI learned the statistical relationships between words. When you type a prompt, ChatGPT is fundamentally playing an extremely advanced game of **"predict the next most logical word."** Because it has read so much, its predictions sound like coherent, thoughtful human text.
# *   **Image Generators (Diffusion Models):** They start with a grid of random visual noise (like TV static) and gradually alter the pixels step-by-step to match the patterns of the text prompt you provided (e.g., "a golden retriever wearing a party hat").
#
# ---
#
# ### 5. Important Reality Check: AI Doesn't "Think"
#
# Despite how smart AI seems, **it has no consciousness, feelings, or actual understanding.**
#
# *   When an AI answers a medical question, it doesn't "know" medicine. It simply knows that certain medical words statistically go together in specific orders based on the textbooks it read.
# *   It is essentially **hyper-advanced statistics and pattern matching** running on supercomputers.
#
# ### Summary / TL;DR
#
# 1.  **Feed Data:** Show the AI millions of examples.
# 2.  **Find Patterns:** The AI uses neural networks to find hidden connections in the data.
# 3.  **Refine Settings:** The AI adjusts its internal math until its predictions are accurate.
# 4.  **Execute:** When given new, unseen data, the AI uses those learned patterns to predict, generate, or solve a problem.

# %%
#pip install -U phidata

# %%
import os

# Set the Google API key
os.environ["GOOGLE_API_KEY"] = "YOUR_API_KEY_HERE"

# %%
api_key = os.getenv("GOOGLE_API_KEY")
print(api_key)
# Out:
# ----------------------

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# models/gemini-3.7-flash
# models/lyria-3-clip-preview
# models/lyria-3-pro-preview
# models/gemini-3.1-flash-tts-preview
# models/gemini-robotics-er-1.6-preview
# models/gemini-robotics-er-2-preview
# models/gemini-2.5-computer-use-preview-10-2025
# models/antigravity-preview-05-2026
# models/deep-research-max-preview-04-2026
# models/deep-research-preview-04-2026
# models/deep-research-pro-preview-12-2025

# %%
from phi.agent import Agent, RunResponse
from phi.model.google import Gemini
import os

# Set the Google API key in the environment if not already done
os.environ["GOOGLE_API_KEY"] = "YOUR_API_KEY_HERE"

# Initialize the agent with the Gemini model
agent = Agent(
    model=Gemini(id="gemini-3.6-flash"),
    markdown=True,
)

# Get the response by running a prompt
run: RunResponse = agent.run(" can you please book the hotel for me for 2 days? from oyo")

# Print the content of the response in the terminal
print(run.content)
# Out:
# I cannot directly place bookings or process payments for you, as I don't have access to your personal account or external booking systems.
#
# However, **I can help you find and choose the best OYO hotel options** for your trip!
#
# To get started, please share the following details:
# * **City/Location:** (e.g., Central Delhi, near Mumbai Airport, Goa)
# * **Dates:** (e.g., Oct 12 to Oct 14)
# * **Number of Guests & Rooms:** (e.g., 2 adults, 1 room)
# * **Budget per night:** (e.g., Under ₹1,500 / $30 per night)
# * **Preferences:** (e.g., Free Wi-Fi, AC, free breakfast, specific amenities)
#
# ---
#
# ### How to complete your booking on OYO:
# 1. Download the **OYO app** or go to [oyorooms.com](https://www.oyorooms.com).
# 2. Enter your **destination**, **check-in/check-out dates**, and **number of guests**.
# 3. Apply filters for **price** or **rating**.
# 4. Select your preferred hotel and click **Book Now**.
